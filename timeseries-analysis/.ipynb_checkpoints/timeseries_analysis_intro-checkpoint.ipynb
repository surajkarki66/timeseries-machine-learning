# %%
import sktime

# %%
from sktime import datasets

# %%
airlines = datasets.load_airline()

# %%
type(airlines)
# Out:
# pandas.core.series.Series

# %%
airlines.head()
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %% [markdown]
# ## Timeseries Data
#
# 1. Univariate: Only one variable varies with time.
# 2. Multivariate: Multiple variables varies with time.

# %%
import matplotlib.pyplot as plt

# %%
airlines.index
# Out:
# PeriodIndex(['1949-01', '1949-02', '1949-03', '1949-04', '1949-05', '1949-06',
#              '1949-07', '1949-08', '1949-09', '1949-10',
#              ...
#              '1960-03', '1960-04', '1960-05', '1960-06', '1960-07', '1960-08',
#              '1960-09', '1960-10', '1960-11', '1960-12'],
#             dtype='period[M]', name='Period', length=144)

# %%
airlines.values
# Out:
# array([112., 118., 132., 129., 121., 135., 148., 148., 136., 119., 104.,
#        118., 115., 126., 141., 135., 125., 149., 170., 170., 158., 133.,
#        114., 140., 145., 150., 178., 163., 172., 178., 199., 199., 184.,
#        162., 146., 166., 171., 180., 193., 181., 183., 218., 230., 242.,
#        209., 191., 172., 194., 196., 196., 236., 235., 229., 243., 264.,
#        272., 237., 211., 180., 201., 204., 188., 235., 227., 234., 264.,
#        302., 293., 259., 229., 203., 229., 242., 233., 267., 269., 270.,
#        315., 364., 347., 312., 274., 237., 278., 284., 277., 317., 313.,
#        318., 374., 413., 405., 355., 306., 271., 306., 315., 301., 356.,
#        348., 355., 422., 465., 467., 404., 347., 305., 336., 340., 318.,
#        362., 348., 363., 435., 491., 505., 404., 359., 310., 337., 360.,
#        342., 406., 396., 420., 472., 548., 559., 463., 407., 362., 405.,
#        417., 391., 419., 461., 472., 535., 622., 606., 508., 461., 390.,
#        432.])

# %%
plt.plot(airlines.values)

# %%
from sktime.utils.plotting import plot_series

# %%
fig, ax = plot_series(airlines)

# %%
fig, ax = plot_series(airlines[:30], airlines[30:])
