# %%
from sktime.forecasting.arima import AutoARIMA
from sktime.utils.plotting import plot_series
from sktime.datasets import load_airline
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.forecasting.model_selection import temporal_train_test_split

import matplotlib.pyplot as plt

# %%
airline = load_airline()

# %%
y_train, y_test = temporal_train_test_split(airline, test_size=36)

# %%
fh = list(range(1, 37))

# %%
forecaster = AutoARIMA(suppress_warnings=True,  
    stepwise=True,            
    seasonal=True,            
    max_order=None,           
    trace=True                )

# %%
forecaster.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=959.218, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1002.826, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=996.373, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=991.646, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1001.531, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=988.670, Time=0.07 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=983.832, Time=0.07 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 2.557 seconds
# AutoARIMA(max_order=None, suppress_warnings=True, trace=True)

# %%
y_pred = forecaster.predict(fh)

# %%
plot_series(y_train, y_test, y_pred, labels=['train', 'test', 'predicted'])
# Out:
# (<Figure size 1600x400 with 1 Axes>,
#  <Axes: ylabel='Number of airline passengers'>)
